# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Read CSV
harvey_data = pd.read_csv("Resources/harvey.csv",index_col=1)
harvey_data
# Out:
#              county  unemployment hurricane
# year
# 2016  Harris County           6.5    Harvey
# 2017  Harris County           6.2    Harvey
# 2018  Harris County           5.6    Harvey
# 2019  Harris County           5.2    Harvey

# %%
fig, ax = plt.subplots()

ax.bar(harvey_data.index, harvey_data['unemployment'])

ax.set_title ("Unemployment in Harris County", fontsize = 18)

ax.set_ylabel("Percentage of Unemployed")

plt.show
# Out:
# <img src="data:image/png;base64,..." width="640">
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# Read CSV
sandy_data = pd.read_csv("Resources/sandy.csv",index_col=1)
sandy_data
# Out:
#                county  unemployment hurricane
# year
# 2011  Atlantic County          14.9     Sandy
# 2012  Atlantic County          14.4     Sandy
# 2013  Atlantic County          12.4     Sandy
# 2014  Atlantic County          11.4     Sandy
# 2015  Atlantic County          10.8     Sandy
# 2016  Atlantic County          10.6     Sandy
# 2017  Atlantic County           8.5     Sandy

# %%
fig, ax = plt.subplots()

ax.bar(sandy_data.index, sandy_data['unemployment'])

ax.set_title ("Unemployment in Atlantic County", fontsize = 18)

ax.set_ylabel("Percentage of Unemployed")

plt.show
# Out:
# <img src="data:image/png;base64,..." width="640">
# <function matplotlib.pyplot.show(*args, **kw)>
